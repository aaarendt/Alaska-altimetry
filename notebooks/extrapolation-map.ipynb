# %% [markdown]
# ### Code to visualize final altimetry output

# %%
# %matplotlib inline
import geopandas as gpd
from pathlib import Path

# %%
data = gpd.read_file("../data/altimetryextrapolation.geojson")

# %%
data.columns
# Out:
# Index(['ergiid', 'name', 'gltype', 'surge', 'glarea', 'bins', 'normbins',
#        'area', 'mean', 'median', 'std', 'surveyed', 'error', 'region',
#        'geometry'],
#       dtype='object')

# %%
# Plot a specific glacier
data.where(data.name == 'Kahiltna Glacier').plot(column='mean', legend = True)
# Out:
# <AxesSubplot:>

# %%
data.region.unique()
# Out:
# array(['Fairweather Glacier Bay', 'Chugach Range', 'Brooks Range',
#        'Wrangell Mountains', 'Kenai Mountains', 'Stikine Icefield',
#        'Coast Range BC', 'St. Elias Mountains', 'Juneau Icefield',
#        'Aluetian Range', 'Alaska Range', None], dtype=object)

# %%
# Plot a region
data.where(data.region == 'Stikine Icefield').plot(column='mean', legend = True)
# Out:
# <AxesSubplot:>
